# %% [markdown]
# # Libraries

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall
from tensorflow.keras.regularizers import l2

# %% [markdown]
# **Pseudocode**
# - upload data (check values)
# - train test split
# - augmentation
# - build model
# - predict
# - custom metrics (see paper for more details)

# %% [markdown]
# # Upload data

# %%
neg_img_dir = '/Users/renatoboemer/signet-ring-cv/data/sig-train-neg'
pos_img_dir = '/Users/renatoboemer/signet-ring-cv/data/sig-train-pos'

# %%
# create a dfs
neg_images = [os.path.join(neg_img_dir, f) for f in os.listdir(neg_img_dir) if f.endswith('.jpeg')]
neg_df = pd.DataFrame(neg_images, columns=['image_path'])
neg_df['label'] = 0

pos_images = [os.path.join(pos_img_dir, f) for f in os.listdir(pos_img_dir) if f.endswith('.jpeg')]
pos_df = pd.DataFrame(pos_images, columns=['image_path'])
pos_df['label'] = 1

# %%
# combine dfs
df = pd.concat([pos_df, neg_df], ignore_index=True)
df.head()
# Out:
#                                           image_path  label
# 0  /Users/renatoboemer/signet-ring-cv/data/sig-tr...      1
# 1  /Users/renatoboemer/signet-ring-cv/data/sig-tr...      1
# 2  /Users/renatoboemer/signet-ring-cv/data/sig-tr...      1
# 3  /Users/renatoboemer/signet-ring-cv/data/sig-tr...      1
# 4  /Users/renatoboemer/signet-ring-cv/data/sig-tr...      1

# %%
df.groupby('label').agg({'image_path': pd.Series.nunique})
# Out:
#        image_path
# label
# 0             378
# 1              77

# %%
image_paths = pos_df['image_path'].unique()

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

train_val_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

train_df, val_df = train_test_split(train_val_df, test_size=0.25, random_state=42) # 0.25 x 0.8 = 0.2

# %% [markdown]
# # Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def create_generator(dataframe, x_col, y_col, image_data_generator, target_size, batch_size, class_mode):
    # temporary df to avoid altering the original
    temp_df = dataframe.copy()
    temp_df[y_col] = temp_df[y_col].astype(str)

    return image_data_generator.flow_from_dataframe(
        dataframe=temp_df,
        x_col=x_col,
        y_col=y_col,
        target_size=target_size,
        batch_size=batch_size,
        class_mode=class_mode
    )

# Define data augmentation parameters for the training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,         # Random rotations in the range of 0-45 degrees
    width_shift_range=0.2,     # Random horizontal shifts
    height_shift_range=0.2,    # Random vertical shifts
    shear_range=0.2,           # Shear transformations
    zoom_range=0.2,            # Random zoom
    horizontal_flip=True,      # Random horizontal flips
    vertical_flip=True,        # Random vertical flips
    fill_mode='nearest'        # Strategy to fill newly created pixels
)

# for the validation generator, usually, we only rescale
val_datagen = ImageDataGenerator(rescale=1./255)

# Create the generators
train_generator = create_generator(
    dataframe=train_df,
    x_col='image_path',
    y_col='label',
    image_data_generator=train_datagen,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

val_generator = create_generator(
    dataframe=val_df,
    x_col='image_path',
    y_col='label',
    image_data_generator=val_datagen,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 273 validated image filenames belonging to 2 classes.
# Found 91 validated image filenames belonging to 2 classes.

# %%
# class distribution
train_df['label'].value_counts()
# Out:
# label
# 0    230
# 1     43
# Name: count, dtype: int64

# %% [markdown]
# # Build Model

# %%
# load pre-trained model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# freeze base model layers
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)


# define model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
# compile
model.compile(optimizer=Adam(learning_rate=0.001), 
              loss='binary_crossentropy', 
              metrics=['accuracy', Recall()])

# # get summary
# model.summary()

# %%
# train
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    validation_data=val_generator,
    validation_steps=len(val_generator),
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 140s 16s/step - loss: 4.9163 - accuracy: 0.8315 - recall_2: 0.0465 - val_loss: 4.1005 - val_accuracy: 0.8462 - val_recall_2: 0.0000e+00
# Epoch 2/50
# 9/9 [==============================] - 131s 15s/step - loss: 3.5992 - accuracy: 0.8462 - recall_2: 0.0465 - val_loss: 2.9749 - val_accuracy: 0.8462 - val_recall_2: 0.0000e+00
# Epoch 3/50
# 9/9 [==============================] - 117s 13s/step - loss: 2.6561 - accuracy: 0.8535 - recall_2: 0.0930 - val_loss: 2.1556 - val_accuracy: 0.8462 - val_recall_2: 0.0000e+00
# Epoch 4/50
# 9/9 [==============================] - 113s 13s/step - loss: 1.9121 - accuracy: 0.8498 - recall_2: 0.0465 - val_loss: 1.5825 - val_accuracy: 0.8571 - val_recall_2: 0.0714
# Epoch 5/50
# 9/9 [==============================] - 150s 17s/step - loss: 1.4407 - accuracy: 0.8608 - recall_2: 0.2791 - val_loss: 1.2043 - val_accuracy: 0.8462 - val_recall_2: 0.0000e+00
# Epoch 6/50
# 9/9 [==============================] - 106s 12s/step - loss: 1.0961 - accuracy: 0.8718 - recall_2: 0.2093 - val_loss: 0.9149 - val_accuracy: 0.8571 - val_recall_2: 0.0714
# Epoch 7/50
# 9/9 [==============================] - 107s 12s/step - loss: 0.8677 - accuracy: 0.8571 - recall_2: 0.1860 - val_loss: 0.7399 - val_accuracy: 0.8571 - val_recall_2: 0.0714
# Epoch 8/50
# 9/9 [==============================] - 108s 12s/step - loss: 0.7075 - accuracy: 0.9048 - recall_2: 0.4884 - val_loss: 0.6329 - val_accuracy: 0.8571 - val_recall_2: 0.0714
# Epoch 9/50
# 9/9 [==============================] - 107s 12s/step - loss: 0.6341 - accuracy: 0.8755 - recall_2: 0.2558 - val_loss: 0.5485 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 10/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.5599 - accuracy: 0.8974 - recall_2: 0.3953 - val_loss: 0.5384 - val_accuracy: 0.8462 - val_recall_2: 0.0000e+00
# Epoch 11/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.5293 - accuracy: 0.8791 - recall_2: 0.3721 - val_loss: 0.4774 - val_accuracy: 0.8571 - val_recall_2: 0.0714
# Epoch 12/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.4723 - accuracy: 0.8864 - recall_2: 0.3256 - val_loss: 0.4352 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 13/50
# 9/9 [==============================] - 104s 12s/step - loss: 0.4707 - accuracy: 0.9011 - recall_2: 0.4419 - val_loss: 0.4787 - val_accuracy: 0.8462 - val_recall_2: 0.0000e+00
# Epoch 14/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.4421 - accuracy: 0.9011 - recall_2: 0.4419 - val_loss: 0.3979 - val_accuracy: 0.9011 - val_recall_2: 0.3571
# Epoch 15/50
# 9/9 [==============================] - 104s 12s/step - loss: 0.4031 - accuracy: 0.9231 - recall_2: 0.5349 - val_loss: 0.3813 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 16/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.3962 - accuracy: 0.9011 - recall_2: 0.4651 - val_loss: 0.4037 - val_accuracy: 0.8571 - val_recall_2: 0.0714
# Epoch 17/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.3776 - accuracy: 0.9121 - recall_2: 0.5116 - val_loss: 0.3838 - val_accuracy: 0.8571 - val_recall_2: 0.0714
# Epoch 18/50
# 9/9 [==============================] - 111s 13s/step - loss: 0.3949 - accuracy: 0.9084 - recall_2: 0.5349 - val_loss: 0.3527 - val_accuracy: 0.9011 - val_recall_2: 0.3571
# Epoch 19/50
# 9/9 [==============================] - 127s 15s/step - loss: 0.3921 - accuracy: 0.8938 - recall_2: 0.3488 - val_loss: 0.3423 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 20/50
# 9/9 [==============================] - 104s 12s/step - loss: 0.3958 - accuracy: 0.8901 - recall_2: 0.4419 - val_loss: 0.3336 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 21/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.3561 - accuracy: 0.9084 - recall_2: 0.5116 - val_loss: 0.3447 - val_accuracy: 0.8681 - val_recall_2: 0.1429
# Epoch 22/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.3482 - accuracy: 0.9084 - recall_2: 0.5116 - val_loss: 0.3192 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 23/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.3481 - accuracy: 0.9048 - recall_2: 0.4651 - val_loss: 0.3137 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 24/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.3472 - accuracy: 0.9048 - recall_2: 0.5581 - val_loss: 0.3911 - val_accuracy: 0.8462 - val_recall_2: 0.0000e+00
# Epoch 25/50
# 9/9 [==============================] - 108s 12s/step - loss: 0.3759 - accuracy: 0.8901 - recall_2: 0.4419 - val_loss: 0.3083 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 26/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.3401 - accuracy: 0.9011 - recall_2: 0.5349 - val_loss: 0.3051 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 27/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.3254 - accuracy: 0.9084 - recall_2: 0.5349 - val_loss: 0.3006 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 28/50
# 9/9 [==============================] - 93s 11s/step - loss: 0.3135 - accuracy: 0.9011 - recall_2: 0.4419 - val_loss: 0.3020 - val_accuracy: 0.9121 - val_recall_2: 0.4286
# Epoch 29/50
# 9/9 [==============================] - 91s 10s/step - loss: 0.3244 - accuracy: 0.9341 - recall_2: 0.7442 - val_loss: 0.2966 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 30/50
# 9/9 [==============================] - 102s 11s/step - loss: 0.3141 - accuracy: 0.9121 - recall_2: 0.5116 - val_loss: 0.2906 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 31/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.3294 - accuracy: 0.8974 - recall_2: 0.5116 - val_loss: 0.3159 - val_accuracy: 0.8681 - val_recall_2: 0.1429
# Epoch 32/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.2979 - accuracy: 0.9304 - recall_2: 0.6047 - val_loss: 0.2835 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 33/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.3205 - accuracy: 0.9048 - recall_2: 0.4884 - val_loss: 0.2887 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 34/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.3123 - accuracy: 0.8974 - recall_2: 0.4651 - val_loss: 0.2792 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 35/50
# 9/9 [==============================] - 106s 13s/step - loss: 0.3264 - accuracy: 0.8938 - recall_2: 0.4651 - val_loss: 0.2852 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 36/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.3009 - accuracy: 0.9121 - recall_2: 0.6047 - val_loss: 0.3138 - val_accuracy: 0.8681 - val_recall_2: 0.1429
# Epoch 37/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.2953 - accuracy: 0.9194 - recall_2: 0.5814 - val_loss: 0.2780 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 38/50
# 9/9 [==============================] - 105s 12s/step - loss: 0.3156 - accuracy: 0.9048 - recall_2: 0.5581 - val_loss: 0.2899 - val_accuracy: 0.9121 - val_recall_2: 0.4286
# Epoch 39/50
# 9/9 [==============================] - 109s 12s/step - loss: 0.2766 - accuracy: 0.9304 - recall_2: 0.5814 - val_loss: 0.2747 - val_accuracy: 0.9451 - val_recall_2: 0.7143
# Epoch 40/50
# 9/9 [==============================] - 128s 14s/step - loss: 0.2939 - accuracy: 0.9267 - recall_2: 0.6279 - val_loss: 0.2900 - val_accuracy: 0.9121 - val_recall_2: 0.4286
# Epoch 41/50
# 9/9 [==============================] - 122s 14s/step - loss: 0.3015 - accuracy: 0.9194 - recall_2: 0.6512 - val_loss: 0.2745 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 42/50
# 9/9 [==============================] - 108s 12s/step - loss: 0.2928 - accuracy: 0.9048 - recall_2: 0.5116 - val_loss: 0.2656 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 43/50
# 9/9 [==============================] - 121s 14s/step - loss: 0.2838 - accuracy: 0.9341 - recall_2: 0.6279 - val_loss: 0.2777 - val_accuracy: 0.9231 - val_recall_2: 0.5000
# Epoch 44/50
# 9/9 [==============================] - 110s 12s/step - loss: 0.2932 - accuracy: 0.9048 - recall_2: 0.4884 - val_loss: 0.2636 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 45/50
# 9/9 [==============================] - 106s 12s/step - loss: 0.2910 - accuracy: 0.9267 - recall_2: 0.6744 - val_loss: 0.2629 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 46/50
# 9/9 [==============================] - 103s 12s/step - loss: 0.3251 - accuracy: 0.8864 - recall_2: 0.5116 - val_loss: 0.3448 - val_accuracy: 0.8681 - val_recall_2: 0.1429
# Epoch 47/50
# 9/9 [==============================] - 103s 12s/step - loss: 0.2866 - accuracy: 0.9231 - recall_2: 0.6279 - val_loss: 0.2653 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 48/50
# 9/9 [==============================] - 104s 12s/step - loss: 0.3313 - accuracy: 0.8791 - recall_2: 0.3721 - val_loss: 0.2638 - val_accuracy: 0.9341 - val_recall_2: 0.5714
# Epoch 49/50
# 9/9 [==============================] - 104s 12s/step - loss: 0.3070 - accuracy: 0.9048 - recall_2: 0.5814 - val_loss: 0.2848 - val_accuracy: 0.9121 - val_recall_2: 0.4286
# Epoch 50/50
# 9/9 [==============================] - 104s 12s/step - loss: 0.2749 - accuracy: 0.9194 - recall_2: 0.5581 - val_loss: 0.2626 - val_accuracy: 0.9341 - val_recall_2: 0.5714

# %%
def plot_history(history):
    metrics = list(history.keys())
    num_metrics = len(metrics) // 2 
    plt.figure(figsize=(6 * num_metrics, 5))

    for i, metric in enumerate(metrics[:num_metrics]):
        plt.subplot(1, num_metrics, i + 1)
        plt.plot(history[metric], label=f'Training {metric.capitalize()}')
        plt.plot(history[f'val_{metric}'], label=f'Validation {metric.capitalize()}')
        plt.title(f'Training and Validation {metric.capitalize()}')
        plt.xlabel('Epoch')
        plt.ylabel(metric.capitalize())
        plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history.history)

# %% [markdown]
# # Predict

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# Convert labels to string for the generator
test_df['label_str'] = test_df['label'].astype(str)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='image_path',
    y_col='label_str',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 91 validated image filenames belonging to 2 classes.

# %%
y_true_numeric = test_df['label'].values

# %%
predictions = model.predict(test_generator)
# Out:
# 3/3 [==============================] - 22s 7s/step

# %% [markdown]
# # Custom Metrics

# %%
def calculate_FPNormal(y_true, y_pred):
    # Convert predictions and true values to boolean
    y_pred_bool = y_pred.astype(bool)
    y_true_bool = y_true.astype(bool)

    # False positives: where the true label is 0 (normal) but predicted as 1 (cancer)
    false_positives = (y_pred_bool & ~y_true_bool)

    # Count false positives in normal cases
    FPNormal = false_positives.sum() / (~y_true_bool).sum()

    return FPNormal

y_true_test = test_df['label'].values

FPNormal = calculate_FPNormal(y_true_test, predictions.round())
print("FPNormal:", FPNormal)
# Out:
# FPNormal: 4.0

# %%
from sklearn.metrics import roc_curve

y_score = predictions

def calculate_FROC(y_true_test, y_score):
    # Compute ROC curve and ROC area for each threshold
    fpr, tpr, thresholds = roc_curve(y_true_test, y_score)

    # Calculate the average number of false positives per image at each threshold
    FPPI = fpr * np.sum(~y_true_test.astype(bool))  # False Positives Per Image

    # FROC is typically represented as a plot of TPR vs FPPI
    return tpr, FPPI, thresholds

# Assuming y_test contains true labels and y_score contains the raw output probabilities from the model
tpr, FPPI, thresholds = calculate_FROC(y_true_test, y_score)

# To plot the FROC curve, you can use matplotlib or any other plotting library

plt.figure()
plt.plot(FPPI, tpr, color='darkorange', lw=2)
plt.xlim([0.0, max(FPPI)])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positives Per Image')
plt.ylabel('True Positive Rate')
plt.title('FROC Curve');
